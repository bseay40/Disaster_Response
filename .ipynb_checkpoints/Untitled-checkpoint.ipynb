# %%
# import libraries
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
#from sklearn.metrics import f1_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SEAY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SEAY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
# load data from database
engine = create_engine('sqlite:///InsertDatabaseName.db')
df = pd.read_sql_table('clean_message_dataset', engine)
X = df['message'] # the message is the predictor
Y = df.iloc[:,4:] # the 36 categories is what we are trying to predict the message falls in.

# %%
def tokenize(text):
    words = word_tokenize(text)
    words = [w for w in words if w not in stopwords.words("english")] # removing stop words
    return words

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)
pipeline.fit(X_train, y_train)
predicted = pipeline.predict(X_test)

# %%
for col in range(0,36,1):
    print(y_test.columns[col], col)
    print(classification_report(y_test.iloc[:,col], predicted[:,col]))
# Out:
# related 0
#               precision    recall  f1-score   support
#
#            0       0.74      0.35      0.48      1516
#            1       0.82      0.96      0.89      4987
#            2       0.57      0.08      0.14        51
#
#     accuracy                           0.81      6554
#    macro avg       0.71      0.46      0.50      6554
# weighted avg       0.80      0.81      0.79      6554
#
# request 1
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      5453
#            1       0.85      0.50      0.63      1101
#
#     accuracy                           0.90      6554
#    macro avg       0.88      0.74      0.78      6554
# weighted avg       0.90      0.90      0.89      6554
#
# offer 2
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6522
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# aid_related 3
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82      3859
#            1       0.76      0.67      0.71      2695
#
#     accuracy                           0.78      6554
#    macro avg       0.77      0.76      0.77      6554
# weighted avg       0.78      0.78      0.77      6554
#
# medical_help 4
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6040
#            1       0.58      0.06      0.10       514
#
#     accuracy                           0.92      6554
#    macro avg       0.75      0.53      0.53      6554
# weighted avg       0.90      0.92      0.89      6554
#
# medical_products 5
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6216
#            1       0.65      0.04      0.08       338
#
#     accuracy                           0.95      6554
#    macro avg       0.80      0.52      0.53      6554
# weighted avg       0.94      0.95      0.93      6554
#
# search_and_rescue 6
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6387
#            1       0.88      0.04      0.08       167
#
#     accuracy                           0.98      6554
#    macro avg       0.93      0.52      0.53      6554
# weighted avg       0.97      0.98      0.96      6554
#
# security 7
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6439
#            1       0.00      0.00      0.00       115
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.98      0.97      6554
#
# military 8
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6344
#            1       0.65      0.07      0.13       210
#
#     accuracy                           0.97      6554
#    macro avg       0.81      0.54      0.56      6554
# weighted avg       0.96      0.97      0.96      6554
#
# child_alone 9
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# water 10
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6128
#            1       0.95      0.34      0.50       426
#
#     accuracy                           0.96      6554
#    macro avg       0.95      0.67      0.74      6554
# weighted avg       0.96      0.96      0.95      6554
#
# food 11
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      5814
#            1       0.85      0.51      0.64       740
#
#     accuracy                           0.94      6554
#    macro avg       0.90      0.75      0.80      6554
# weighted avg       0.93      0.94      0.93      6554
#
# shelter 12
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6012
#            1       0.84      0.33      0.47       542
#
#     accuracy                           0.94      6554
#    macro avg       0.89      0.66      0.72      6554
# weighted avg       0.93      0.94      0.93      6554
#
# clothing 13
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6465
#            1       1.00      0.08      0.15        89
#
#     accuracy                           0.99      6554
#    macro avg       0.99      0.54      0.57      6554
# weighted avg       0.99      0.99      0.98      6554
#
# money 14
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6407
#            1       1.00      0.03      0.07       147
#
#     accuracy                           0.98      6554
#    macro avg       0.99      0.52      0.53      6554
# weighted avg       0.98      0.98      0.97      6554
#
# missing_people 15
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6478
#            1       1.00      0.03      0.05        76
#
#     accuracy                           0.99      6554
#    macro avg       0.99      0.51      0.52      6554
# weighted avg       0.99      0.99      0.98      6554
#
# refugees 16
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6351
#            1       0.82      0.04      0.08       203
#
#     accuracy                           0.97      6554
#    macro avg       0.89      0.52      0.53      6554
# weighted avg       0.97      0.97      0.96      6554
#
# death 17
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6237
#            1       0.91      0.10      0.18       317
#
#     accuracy                           0.96      6554
#    macro avg       0.94      0.55      0.58      6554
# weighted avg       0.95      0.96      0.94      6554
#
# other_aid 18
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5704
#            1       0.61      0.02      0.04       850
#
#     accuracy                           0.87      6554
#    macro avg       0.74      0.51      0.48      6554
# weighted avg       0.84      0.87      0.82      6554
#
# infrastructure_related 19
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6158
#            1       0.20      0.00      0.00       396
#
#     accuracy                           0.94      6554
#    macro avg       0.57      0.50      0.49      6554
# weighted avg       0.89      0.94      0.91      6554
#
# transport 20
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6242
#            1       0.75      0.11      0.19       312
#
#     accuracy                           0.96      6554
#    macro avg       0.85      0.55      0.58      6554
# weighted avg       0.95      0.96      0.94      6554
#
# buildings 21
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6250
#            1       0.78      0.14      0.24       304
#
#     accuracy                           0.96      6554
#    macro avg       0.87      0.57      0.61      6554
# weighted avg       0.95      0.96      0.94      6554
#
# electricity 22
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6421
#            1       0.67      0.02      0.03       133
#
#     accuracy                           0.98      6554
#    macro avg       0.82      0.51      0.51      6554
# weighted avg       0.97      0.98      0.97      6554
#
# tools 23
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6519
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# hospitals 24
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6479
#            1       0.00      0.00      0.00        75
#
#     accuracy                           0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# shops 25
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6529
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# aid_centers 26
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6490
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.98      0.99      0.99      6554
#
# other_infrastructure 27
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6288
#            1       0.00      0.00      0.00       266
#
#     accuracy                           0.96      6554
#    macro avg       0.48      0.50      0.49      6554
# weighted avg       0.92      0.96      0.94      6554
#
# weather_related 28
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      4724
#            1       0.86      0.66      0.75      1830
#
#     accuracy                           0.87      6554
#    macro avg       0.87      0.81      0.83      6554
# weighted avg       0.87      0.87      0.87      6554
#
# floods 29
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6001
#            1       0.92      0.46      0.61       553
#
#     accuracy                           0.95      6554
#    macro avg       0.93      0.73      0.79      6554
# weighted avg       0.95      0.95      0.94      6554
#
# storm 30
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5955
#            1       0.80      0.48      0.60       599
#
#     accuracy                           0.94      6554
#    macro avg       0.88      0.73      0.78      6554
# weighted avg       0.94      0.94      0.93      6554
#
# fire 31
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6493
#            1       0.67      0.03      0.06        61
#
#     accuracy                           0.99      6554
#    macro avg       0.83      0.52      0.53      6554
# weighted avg       0.99      0.99      0.99      6554
#
# earthquake 32
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      5939
#            1       0.89      0.74      0.81       615
#
#     accuracy                           0.97      6554
#    macro avg       0.93      0.86      0.89      6554
# weighted avg       0.97      0.97      0.97      6554
#
# cold 33
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6428
#            1       0.62      0.06      0.12       126
#
#     accuracy                           0.98      6554
#    macro avg       0.80      0.53      0.55      6554
# weighted avg       0.97      0.98      0.97      6554
#
# other_weather 34
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6211
#            1       0.60      0.03      0.05       343
#
#     accuracy                           0.95      6554
#    macro avg       0.77      0.51      0.51      6554
# weighted avg       0.93      0.95      0.93      6554
#
# direct_report 35
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      5319
#            1       0.79      0.37      0.50      1235
#
#     accuracy                           0.86      6554
#    macro avg       0.83      0.67      0.71      6554
# weighted avg       0.86      0.86      0.84      6554
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
parameters = {
    'vect__strip_accents': ['ascii','unicode', None],
    'vect__lowercase': [True, False],
    'tfidf__sublinear_tf': [True, False],
}

cv = GridSearchCV(pipeline, param_grid=parameters)
cv.fit(X_train, y_train)
predicted_grid = cv.predict(X_test)

# %%
for col in range(0,36,1):
    print(y_test.columns[col], col)
    print(classification_report(y_test.iloc[:,col], predicted_grid[:,col]))
# Out:
# related 0
#               precision    recall  f1-score   support
#
#            0       0.74      0.35      0.48      1516
#            1       0.82      0.96      0.89      4987
#            2       0.44      0.08      0.13        51
#
#     accuracy                           0.81      6554
#    macro avg       0.67      0.46      0.50      6554
# weighted avg       0.80      0.81      0.79      6554
#
# request 1
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      5453
#            1       0.85      0.49      0.62      1101
#
#     accuracy                           0.90      6554
#    macro avg       0.88      0.74      0.78      6554
# weighted avg       0.90      0.90      0.89      6554
#
# offer 2
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6522
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# aid_related 3
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82      3859
#            1       0.76      0.67      0.71      2695
#
#     accuracy                           0.78      6554
#    macro avg       0.77      0.76      0.76      6554
# weighted avg       0.77      0.78      0.77      6554
#
# medical_help 4
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6040
#            1       0.59      0.05      0.10       514
#
#     accuracy                           0.92      6554
#    macro avg       0.76      0.52      0.53      6554
# weighted avg       0.90      0.92      0.89      6554
#
# medical_products 5
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6216
#            1       0.78      0.06      0.12       338
#
#     accuracy                           0.95      6554
#    macro avg       0.86      0.53      0.54      6554
# weighted avg       0.94      0.95      0.93      6554
#
# search_and_rescue 6
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6387
#            1       0.90      0.05      0.10       167
#
#     accuracy                           0.98      6554
#    macro avg       0.94      0.53      0.54      6554
# weighted avg       0.97      0.98      0.97      6554
#
# security 7
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6439
#            1       0.00      0.00      0.00       115
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.98      0.97      6554
#
# military 8
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6344
#            1       0.75      0.04      0.08       210
#
#     accuracy                           0.97      6554
#    macro avg       0.86      0.52      0.53      6554
# weighted avg       0.96      0.97      0.96      6554
#
# child_alone 9
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# water 10
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6128
#            1       0.93      0.33      0.49       426
#
#     accuracy                           0.95      6554
#    macro avg       0.94      0.67      0.73      6554
# weighted avg       0.95      0.95      0.94      6554
#
# food 11
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      5814
#            1       0.85      0.48      0.61       740
#
#     accuracy                           0.93      6554
#    macro avg       0.89      0.73      0.79      6554
# weighted avg       0.93      0.93      0.92      6554
#
# shelter 12
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6012
#            1       0.83      0.33      0.47       542
#
#     accuracy                           0.94      6554
#    macro avg       0.89      0.66      0.72      6554
# weighted avg       0.93      0.94      0.93      6554
#
# clothing 13
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6465
#            1       0.83      0.06      0.11        89
#
#     accuracy                           0.99      6554
#    macro avg       0.91      0.53      0.55      6554
# weighted avg       0.99      0.99      0.98      6554
#
# money 14
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6407
#            1       1.00      0.04      0.08       147
#
#     accuracy                           0.98      6554
#    macro avg       0.99      0.52      0.53      6554
# weighted avg       0.98      0.98      0.97      6554
#
# missing_people 15
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6478
#            1       1.00      0.01      0.03        76
#
#     accuracy                           0.99      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.99      0.99      0.98      6554
#
# refugees 16
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6351
#            1       0.88      0.03      0.07       203
#
#     accuracy                           0.97      6554
#    macro avg       0.92      0.52      0.53      6554
# weighted avg       0.97      0.97      0.96      6554
#
# death 17
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6237
#            1       0.82      0.12      0.20       317
#
#     accuracy                           0.96      6554
#    macro avg       0.89      0.56      0.59      6554
# weighted avg       0.95      0.96      0.94      6554
#
# other_aid 18
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5704
#            1       0.71      0.03      0.07       850
#
#     accuracy                           0.87      6554
#    macro avg       0.79      0.52      0.50      6554
# weighted avg       0.85      0.87      0.82      6554
#
# infrastructure_related 19
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6158
#            1       0.00      0.00      0.00       396
#
#     accuracy                           0.94      6554
#    macro avg       0.47      0.50      0.48      6554
# weighted avg       0.88      0.94      0.91      6554
#
# transport 20
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6242
#            1       0.74      0.10      0.18       312
#
#     accuracy                           0.96      6554
#    macro avg       0.85      0.55      0.58      6554
# weighted avg       0.95      0.96      0.94      6554
#
# buildings 21
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6250
#            1       0.80      0.16      0.27       304
#
#     accuracy                           0.96      6554
#    macro avg       0.88      0.58      0.62      6554
# weighted avg       0.95      0.96      0.95      6554
#
# electricity 22
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6421
#            1       0.83      0.04      0.07       133
#
#     accuracy                           0.98      6554
#    macro avg       0.91      0.52      0.53      6554
# weighted avg       0.98      0.98      0.97      6554
#
# tools 23
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6519
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# hospitals 24
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6479
#            1       0.00      0.00      0.00        75
#
#     accuracy                           0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# shops 25
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6529
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# aid_centers 26
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6490
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.98      0.99      0.99      6554
#
# other_infrastructure 27
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6288
#            1       0.00      0.00      0.00       266
#
#     accuracy                           0.96      6554
#    macro avg       0.48      0.50      0.49      6554
# weighted avg       0.92      0.96      0.94      6554
#
# weather_related 28
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      4724
#            1       0.85      0.68      0.75      1830
#
#     accuracy                           0.88      6554
#    macro avg       0.87      0.82      0.84      6554
# weighted avg       0.87      0.88      0.87      6554
#
# floods 29
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6001
#            1       0.91      0.42      0.58       553
#
#     accuracy                           0.95      6554
#    macro avg       0.93      0.71      0.77      6554
# weighted avg       0.95      0.95      0.94      6554
#
# storm 30
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5955
#            1       0.81      0.46      0.59       599
#
#     accuracy                           0.94      6554
#    macro avg       0.88      0.72      0.78      6554
# weighted avg       0.94      0.94      0.93      6554
#
# fire 31
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6493
#            1       0.80      0.07      0.12        61
#
#     accuracy                           0.99      6554
#    macro avg       0.90      0.53      0.56      6554
# weighted avg       0.99      0.99      0.99      6554
#
# earthquake 32
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SEAY\Anaconda3\envs\py3_env\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      5939
#            1       0.89      0.75      0.81       615
#
#     accuracy                           0.97      6554
#    macro avg       0.93      0.87      0.90      6554
# weighted avg       0.97      0.97      0.97      6554
#
# cold 33
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6428
#            1       0.75      0.07      0.13       126
#
#     accuracy                           0.98      6554
#    macro avg       0.87      0.54      0.56      6554
# weighted avg       0.98      0.98      0.97      6554
#
# other_weather 34
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6211
#            1       0.62      0.01      0.03       343
#
#     accuracy                           0.95      6554
#    macro avg       0.79      0.51      0.50      6554
# weighted avg       0.93      0.95      0.92      6554
#
# direct_report 35
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      5319
#            1       0.80      0.37      0.50      1235
#
#     accuracy                           0.86      6554
#    macro avg       0.84      0.67      0.71      6554
# weighted avg       0.86      0.86      0.84      6554
